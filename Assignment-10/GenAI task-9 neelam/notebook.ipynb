# %%
import pandas as pd

sales = {
    'Day': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'],
    'Revenue': [1200, 1500, 900, 2000, 1800]
}

df = pd.DataFrame(sales)

# %%
df['Revenue'].plot(kind='line', title='Revenue vs Day').plot()
# Out:
# []
